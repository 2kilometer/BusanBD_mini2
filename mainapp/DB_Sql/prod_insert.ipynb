# %%
import pandas as pd
import cx_Oracle
from sqlalchemy import create_engine
# 엑셀 파일을 데이터프레임으로 읽기
df = pd.read_excel('../../prod최종본.xlsx')
#df = pd.read_csv('../../../disease테이블.csv', encoding=\"euc-kr\")

# %%
df
# Out:
#               prod_name                                           prod_eff  \
# 0          아라비아검(아카시아검)                                배변활동 원활에 도움을 줄 수 있음
# 1                 베타카로틴  (1) 어두운 곳에서 시각 적응을 위해 필요_x000D_\n(2) 피부와 점막을 형...
# 2                 베타카로틴  (1) 어두운 곳에서 시각 적응을 위해 필요_x000D_\n(2) 피부와 점막을 형...
# 3                 베타카로틴  (1) 어두운 곳에서 시각 적응을 위해 필요_x000D_\n(2) 피부와 점막을 형...
# 4                   비오틴                   (1) 지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# ..                  ...                                                ...
# 493              돌외잎추출물                          스트레스로 인한 긴장완화에 도움을 줄 수 있음
# 494              오미자추출물                  갱년기 여성 건강에 도움을 줄 수 있음(생리활성기능 2등급)
# 495       레몬 밤 추출물 혼합분말                        체지방 감소에 도움을 줄 수 있음 (기타기능II)
# 496       호로파종자 등 추출복합물                             남성의 갱년기 건강에 도움을 줄 수 있음
# 497  세리포리아 락세라타 균사체 배양물                                   혈당조절에 도움을 줄 수 있음
#
#      prod_m_num  prod_max  prod_min prod_unit  \
# 0          11.0     20.01    19.990         g
# 1           7.0      7.00     0.420        mg
# 2           8.0      7.00     0.420        mg
# 3          28.0      7.00     0.420        mg
# 4           5.0      0.90     0.009        mg
# ..          ...       ...       ...       ...
# 493         2.0    400.00   400.000        mg
# 494        15.0    783.00   783.000      mg/일
# 495        12.0   1380.00  1380.000      mg/일
# 496        15.0    400.00   400.000      mg/일
# 497        14.0      3.00     3.000       g/일
#
#                                              prod_warn prod_middle
# 0                           반드시 충분한 물과 함께 섭취할 것 (액상제외)           장
# 1    (1) 흡연자는 섭취 시 전문가와 상담할 것_x000D_\n(2) 이상사례 발생 시...           눈
# 2    (1) 흡연자는 섭취 시 전문가와 상담할 것_x000D_\n(2) 이상사례 발생 시...          피부
# 3    (1) 흡연자는 섭취 시 전문가와 상담할 것_x000D_\n(2) 이상사례 발생 시...        상피세포
# 4                    (1) 이상사례 발생 시 섭취를 중단하고 전문가와 상담할 것          피로
# ..                                                 ...         ...
# 493  -과량 섭취 시 위장장애(구토와 위장운동 증가)가 발생할 수 있음_x000D_\n-...       긴장 완화
# 494                                                NaN         호르몬
# 495  -알레르기 반응이 나타날 경우에는 섭취를 중단하시기 바랍니다_x000D_\n-섭취 ...         체지방
# 496                             땅콩 알레르기가 있는 사람은 섭취에 주의         호르몬
# 497  -영·유아, 어린이, 임산부 및 수유부는 섭취에 주의_x000D_\n-알레르기 체질...          혈당
#
# [498 rows x 8 columns]

# %%
dsn = cx_Oracle.makedsn('localhost', 1521, 'xe')
minipro = "minipro"
dbdb = "dbdb"
engine = create_engine(f'oracle://{minipro}:{dbdb}@{dsn}')
df.to_sql("disease", engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:1934, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1933     if not evt_handled:
# -> 1934         self.dialect.do_executemany(
#    1935             cursor,
#    1936             str_statement,
#    1937             effective_parameters,
#    1938             context,
#    1939         )
#    1940 elif not effective_parameters and context.no_parameters:
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\dialects\oracle\cx_oracle.py:1431, in OracleDialect_cx_oracle.do_executemany(self, cursor, statement, parameters, context)
#    1430     parameters = list(parameters)
# -> 1431 cursor.executemany(statement, parameters)
#
# DatabaseError: ORA-00904: "PROD_MIDDLE": 부적합한 식별자
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[5], line 5
#       3 dbdb = "dbdb"
#       4 engine = create_engine(f'oracle://{minipro}:{dbdb}@{dsn}')
# ----> 5 df.to_sql("disease", engine, if_exists='append', index=False)
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\pandas\core\generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\pandas\io\sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\pandas\io\sql.py:1920, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1908 sql_engine = get_engine(engine)
#    1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    (...)
#    1917     dtype=dtype,
#    1918 )
# -> 1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    1923     frame=frame,
#    1924     name=name,
#    1925     index=index,
#    1926     schema=schema,
#    1927     chunksize=chunksize,
#    1928     method=method,
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#    1933 return total_inserted
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\pandas\io\sql.py:1470, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1468 if re.search(msg, err_text):
#    1469     raise ValueError("inf cannot be used with MySQL") from err
# -> 1470 raise err
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\pandas\io\sql.py:1461, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1458 from sqlalchemy import exc
#    1460 try:
# -> 1461     return table.insert(chunksize=chunksize, method=method)
#    1462 except exc.StatementError as err:
#    1463     # GH34431
#    1464     # https://stackoverflow.com/a/67358288/6067848
#    1465     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1466     )|inf can not be used with MySQL"""
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\pandas\io\sql.py:1023, in SQLTable.insert(self, chunksize, method)
#    1020     break
#    1022 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1023 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1024 # GH 46891
#    1025 if is_integer(num_inserted):
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\pandas\io\sql.py:929, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     917 """
#     918 Execute SQL statement inserting data
#     919
#    (...)
#     926    Each item contains a list of values to be inserted
#     927 """
#     928 data = [dict(zip(keys, row)) for row in data_iter]
# --> 929 result = conn.execute(self.table.insert(), data)
#     930 return result.rowcount
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:1412, in Connection.execute(self, statement, parameters, execution_options)
#    1410     raise exc.ObjectNotExecutableError(statement) from err
#    1411 else:
# -> 1412     return meth(
#    1413         self,
#    1414         distilled_parameters,
#    1415         execution_options or NO_OPTIONS,
#    1416     )
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\sql\elements.py:483, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     481     if TYPE_CHECKING:
#     482         assert isinstance(self, Executable)
# --> 483     return connection._execute_clauseelement(
#     484         self, distilled_params, execution_options
#     485     )
#     486 else:
#     487     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:1635, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1623 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1624     "compiled_cache", self.engine._compiled_cache
#    1625 )
#    1627 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1628     dialect=dialect,
#    1629     compiled_cache=compiled_cache,
#    (...)
#    1633     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1634 )
# -> 1635 ret = self._execute_context(
#    1636     dialect,
#    1637     dialect.execution_ctx_cls._init_compiled,
#    1638     compiled_sql,
#    1639     distilled_parameters,
#    1640     execution_options,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     elem,
#    1644     extracted_params,
#    1645     cache_hit=cache_hit,
#    1646 )
#    1647 if has_events:
#    1648     self.dispatch.after_execute(
#    1649         self,
#    1650         elem,
#    (...)
#    1654         ret,
#    1655     )
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:1844, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1839     return self._exec_insertmany_context(
#    1840         dialect,
#    1841         context,
#    1842     )
#    1843 else:
# -> 1844     return self._exec_single_context(
#    1845         dialect, context, statement, parameters
#    1846     )
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:1984, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1981     result = context._setup_result_proxy()
#    1983 except BaseException as e:
# -> 1984     self._handle_dbapi_exception(
#    1985         e, str_statement, effective_parameters, cursor, context
#    1986     )
#    1988 return result
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:2339, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2337 elif should_wrap:
#    2338     assert sqlalchemy_exception is not None
# -> 2339     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2340 else:
#    2341     assert exc_info[1] is not None
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:1934, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1932                 break
#    1933     if not evt_handled:
# -> 1934         self.dialect.do_executemany(
#    1935             cursor,
#    1936             str_statement,
#    1937             effective_parameters,
#    1938             context,
#    1939         )
#    1940 elif not effective_parameters and context.no_parameters:
#    1941     if self.dialect._has_events:
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\dialects\oracle\cx_oracle.py:1431, in OracleDialect_cx_oracle.do_executemany(self, cursor, statement, parameters, context)
#    1429 if isinstance(parameters, tuple):
#    1430     parameters = list(parameters)
# -> 1431 cursor.executemany(statement, parameters)
#
# DatabaseError: (cx_Oracle.DatabaseError) ORA-00904: "PROD_MIDDLE": 부적합한 식별자
# [SQL: INSERT INTO disease (prod_name, prod_eff, prod_m_num, prod_max, prod_min, prod_unit, prod_warn, prod_middle) VALUES (:prod_name, :prod_eff, :prod_m_num, :prod_max, :prod_min, :prod_unit, :prod_warn, :prod_middle)]
# [parameters: [{'prod_name': '아라비아검(아카시아검)', 'prod_eff': '배변활동 원활에 도움을 줄 수 있음', 'prod_m_num': 11.0, 'prod_max': 20.01, 'prod_min': 19.99, 'prod_unit': 'g', 'prod_warn': '반드시 충분한 물과 함께 섭취할 것 (액상제외)', 'prod_middle': '장'}, {'prod_name': '베타카로틴', 'prod_eff': '(1) 어두운 곳에서 시각 적응을 위해 필요_x000D_\n(2) 피부와 점막을 형성하고 기능을 유지하는데 필요_x000D_\n(3) 상피세포의 성장과 발달에 필요', 'prod_m_num': 7.0, 'prod_max': 7.0, 'prod_min': 0.42, 'prod_unit': 'mg', 'prod_warn': '(1) 흡연자는 섭취 시 전문가와 상담할 것_x000D_\n(2) 이상사례 발생 시 섭취를 중단하고 전문가와 상담할 것', 'prod_middle': '눈'}, {'prod_name': '베타카로틴', 'prod_eff': '(1) 어두운 곳에서 시각 적응을 위해 필요_x000D_\n(2) 피부와 점막을 형성하고 기능을 유지하는데 필요_x000D_\n(3) 상피세포의 성장과 발달에 필요', 'prod_m_num': 8.0, 'prod_max': 7.0, 'prod_min': 0.42, 'prod_unit': 'mg', 'prod_warn': '(1) 흡연자는 섭취 시 전문가와 상담할 것_x000D_\n(2) 이상사례 발생 시 섭취를 중단하고 전문가와 상담할 것', 'prod_middle': '피부'}, {'prod_name': '베타카로틴', 'prod_eff': '(1) 어두운 곳에서 시각 적응을 위해 필요_x000D_\n(2) 피부와 점막을 형성하고 기능을 유지하는데 필요_x000D_\n(3) 상피세포의 성장과 발달에 필요', 'prod_m_num': 28.0, 'prod_max': 7.0, 'prod_min': 0.42, 'prod_unit': 'mg', 'prod_warn': '(1) 흡연자는 섭취 시 전문가와 상담할 것_x000D_\n(2) 이상사례 발생 시 섭취를 중단하고 전문가와 상담할 것', 'prod_middle': '상피세포'}, {'prod_name': '비오틴', 'prod_eff': '(1) 지방, 탄수화물, 단백질 대사와 에너지 생성에 필요', 'prod_m_num': 5.0, 'prod_max': 0.9, 'prod_min': 0.009, 'prod_unit': 'mg', 'prod_warn': '(1) 이상사례 발생 시 섭취를 중단하고 전문가와 상담할 것', 'prod_middle': '피로'}, {'prod_name': '비오틴', 'prod_eff': '(1) 지방, 탄수화물, 단백질 대사와 에너지 생성에 필요', 'prod_m_num': 13.0, 'prod_max': 0.9, 'prod_min': 0.009, 'prod_unit': 'mg', 'prod_warn': '(1) 이상사례 발생 시 섭취를 중단하고 전문가와 상담할 것', 'prod_middle': '흡수'}, {'prod_name': '공액리놀레산', 'prod_eff': '①과체중인 성인의 체지방 감소에 도움을 줄 수 있음', 'prod_m_num': 12.0, 'prod_max': 4.2, 'prod_min': 1.4, 'prod_unit': 'g', 'prod_warn': '위장장애가 발생할 수 있음_x000D_\n영·유아, 임산부는 섭취를 삼가야 함_x000D_\n식사조절, 운동을 병행하는 것이 체지방 감소에 효과적임', 'prod_middle': '체지방'}, {'prod_name': '가르시니아캄보지아 추출물', 'prod_eff': '탄수화물이 지방으로 합성되는 것을 억제하여 체지방 감소에 도움을 줄 수 있음', 'prod_m_num': 12.0, 'prod_max': 2800.0, 'prod_min': 750.0, 'prod_unit': 'mg', 'prod_warn': '(가) 어린이, 임산부 및 수유부는 섭취를 피할 것_x000D_\n(나) 간·신장·심장질환, 알레르기 및 천식이 있거나 의약품 복용 시 전문가와 상담할 것_x000D_\n(다) 이상사례 발생 시 섭취를 중단하고 전문가와 상담할 것', 'prod_middle': '체지방'}  ... displaying 10 of 498 total bound parameter sets ...  {'prod_name': '호로파종자 등 추출복합물', 'prod_eff': '남성의 갱년기 건강에 도움을 줄 수 있음', 'prod_m_num': 15.0, 'prod_max': 400.0, 'prod_min': 400.0, 'prod_unit': 'mg/일', 'prod_warn': '땅콩 알레르기가 있는 사람은 섭취에 주의', 'prod_middle': '호르몬'}, {'prod_name': '세리포리아 락세라타 균사체 배양물', 'prod_eff': '혈당조절에 도움을 줄 수 있음', 'prod_m_num': 14.0, 'prod_max': 3.0, 'prod_min': 3.0, 'prod_unit': 'g/일', 'prod_warn': '-영·유아, 어린이, 임산부 및 수유부는 섭취에 주의_x000D_\n-알레르기 체질이거나 특정질환이 있는 분은 섭취 전 의사와 상담', 'prod_middle': '혈당'}]]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)
