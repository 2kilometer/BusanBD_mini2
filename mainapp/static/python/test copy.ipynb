# %%
import pandas as pd
import cx_Oracle
from sqlalchemy import create_engine

# 엑셀 파일을 데이터프레임으로 읽기
# df = pd.read_csv('../../../prod최종본.csv' , encoding='euc-kr')
df = pd.read_csv('../../../disease테이블.csv' , encoding='euc-kr')

# %%
df
# Out:
#      dis_rank dis_code     dis_top  dis_m_num dis_middle          dis_id  \
# 0           1  H43-H45         감각계        6.0     구강(치아)    치아및지지구조의기타장애
# 1           2      J04         기관계       30.0        기관지  급성기관지염및급성세기관지염
# 2           3  L80-L99         감각계        8.0         피부    기타피부및피하조직의질환
# 3           4  J00-J06         기관계       30.0        기관지       기타급성상기도감염
# 4           5      I33  신체방어 및 면역계       21.0         면역     급성인두염및급성편도염
# ..        ...      ...         ...        ...        ...             ...
# 186       130      C44         비뇨계       27.0    신장 및 요로      기타요도의악성신생물
# 187       131      E66      소화·대사계       12.0        체지방              비만
# 188       131      E66      소화·대사계       13.0         흡수              비만
# 189       131      E66        내분비계       14.0         혈당              비만
# 190       131      E66        내분비계       15.0        호르몬              비만
#
#     dis_age1 dis_age2 dis_age3
# 0        50대      40대      30대
# ...

# %%
# Out:
#    순위 질병분류\n코드            한글명칭 Most_Common_Age_Group  \
# 0   1  H43-H45    치아및지지구조의기타장애                   50대
# 1   2      J04  급성기관지염및급성세기관지염                10세 미만
# 2   3  L80-L99    기타피부및피하조직의질환                   50대
# 3   4  J00-J06       기타급성상기도감염                10세 미만
# 4   5      I33     급성인두염및급성편도염                10세 미만
#
#   2nd_Most_Common_Age_Group 3rd_Most_Common_Age_Group 질병코드
# 0                       40대                       30대    6
# 1                       30대                       40대   30
# 2                       40대                       30대    8
# 3                       30대                       40대   30
# 4                       30대                       40대   21
