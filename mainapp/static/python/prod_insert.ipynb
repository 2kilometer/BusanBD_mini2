# %%
import pandas as pd
import cx_Oracle
from sqlalchemy import create_engine

# 엑셀 파일을 데이터프레임으로 읽기
#df = pd.read_excel('../../../prod최종본.xlsx')
df = pd.read_csv('../../../disease테이블.csv', encoding="euc-kr")

# %%
df = df.astype(str)

# %%
df
# Out:
#     dis_rank dis_code          dis_id dis_age1 dis_age2 dis_age3 dis_m_num  \
# 0          1  H43-H45    치아및지지구조의기타장애      50대      40대      30대         6
# 1          2      J04  급성기관지염및급성세기관지염   10세 미만      30대      40대        30
# 2          3  L80-L99    기타피부및피하조직의질환      50대      40대      30대         8
# 3          4  J00-J06       기타급성상기도감염   10세 미만      30대      40대        30
# 4          5      I33     급성인두염및급성편도염   10세 미만      30대      40대        21
# ..       ...      ...             ...      ...      ...      ...       ...
# 185      130      C44      기타요도의악성신생물      50대   70대 이상      60대        27
# 186      131      E66              비만      30대      40대      50대        12
# 187      131      E66              비만      30대      40대      50대        13
# 188      131      E66              비만      30대      40대      50대        14
# 189      131      E66              비만      30대      40대      50대        15
#
#         dis_top dis_middle
# 0           감각계     구강(치아)
# 1           기관계        기관지
# 2           감각계         피부
# 3           기관계        기관지
# 4    신체방어 및 면역계         면역
# ..          ...        ...
# 185         비뇨계    신장 및 요로
# 186      소화·대사계        체지방
# 187      소화·대사계         흡수
# 188        내분비계         혈당
# 189        내분비계        호르몬
#
# [190 rows x 9 columns]

# %%
dsn = cx_Oracle.makedsn('localhost', 1521, 'xe')
minipro = "minipro"
dbdb = "dbdb"

engine = create_engine(f'oracle://{minipro}:{dbdb}@{dsn}')

df.to_sql("disease", engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# DatabaseError: ORA-02449: 외래 키에 의해 참조되는 고유/기본 키가 테이블에 있습니다
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[8], line 7
#       3 dbdb = "dbdb"
#       5 engine = create_engine(f'oracle://{minipro}:{dbdb}@{dsn}')
# ----> 7 df.to_sql("disease", engine, if_exists='replace', index=False)
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\pandas\core\generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\pandas\io\sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\pandas\io\sql.py:1910, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1860 """
#    1861 Write records stored in a DataFrame to a SQL database.
#    1862
#    (...)
#    1906     Any additional kwargs are passed to the engine.
#    1907 """
#    1908 sql_engine = get_engine(engine)
# -> 1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    1913     if_exists=if_exists,
#    1914     index=index,
#    1915     index_label=index_label,
#    1916     schema=schema,
#    1917     dtype=dtype,
#    1918 )
#    1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    (...)
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\pandas\io\sql.py:1814, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1802             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1804 table = SQLTable(
#    1805     name,
#    1806     self,
#    (...)
#    1812     dtype=dtype,
#    1813 )
# -> 1814 table.create()
#    1815 return table
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\pandas\io\sql.py:907, in SQLTable.create(self)
#     905     raise ValueError(f"Table '{self.name}' already exists.")
#     906 if self.if_exists == "replace":
# --> 907     self.pd_sql.drop_table(self.name, self.schema)
#     908     self._execute_create()
#     909 elif self.if_exists == "append":
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\pandas\io\sql.py:1963, in SQLDatabase.drop_table(self, table_name, schema)
#    1961 self.meta.reflect(bind=self.con, only=[table_name], schema=schema)
#    1962 with self.run_transaction():
# -> 1963     self.get_table(table_name, schema).drop(bind=self.con)
#    1964 self.meta.clear()
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\sql\schema.py:1303, in Table.drop(self, bind, checkfirst)
#    1293 def drop(self, bind: _CreateDropBind, checkfirst: bool = False) -> None:
#    1294     """Issue a ``DROP`` statement for this
#    1295     :class:`_schema.Table`, using the given
#    1296     :class:`.Connection` or :class:`.Engine` for connectivity.
#    (...)
#    1301
#    1302     """
# -> 1303     bind._run_ddl_visitor(ddl.SchemaDropper, self, checkfirst=checkfirst)
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:2443, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2431 def _run_ddl_visitor(
#    2432     self,
#    2433     visitorcallable: Type[Union[SchemaGenerator, SchemaDropper]],
#    2434     element: SchemaItem,
#    2435     **kwargs: Any,
#    2436 ) -> None:
#    2437     """run a DDL visitor.
#    2438
#    2439     This method is only here so that the MockConnection can change the
#    2440     options given to the visitor so that "checkfirst" is skipped.
#    2441
#    2442     """
# -> 2443     visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\sql\visitors.py:670, in ExternalTraversal.traverse_single(self, obj, **kw)
#     668 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     669 if meth:
# --> 670     return meth(obj, **kw)
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\sql\ddl.py:1145, in SchemaDropper.visit_table(self, table, drop_ok, _is_metadata_operation, _ignore_sequences)
#    1138     return
#    1140 with self.with_ddl_events(
#    1141     table,
#    1142     checkfirst=self.checkfirst,
#    1143     _is_metadata_operation=_is_metadata_operation,
#    1144 ):
# -> 1145     DropTable(table)._invoke_with(self.connection)
#    1147     # traverse client side defaults which may refer to server-side
#    1148     # sequences. noting that some of these client side defaults may
#    1149     # also be set up as server side defaults
#    (...)
#    1152     # #associating-a-sequence-as-the-server-side-
#    1153     # default), so have to be dropped after the table is dropped.
#    1154     for column in table.columns:
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\sql\ddl.py:315, in ExecutableDDLElement._invoke_with(self, bind)
#     313 def _invoke_with(self, bind):
#     314     if self._should_execute(self.target, bind):
# --> 315         return bind.execute(self)
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:1412, in Connection.execute(self, statement, parameters, execution_options)
#    1410     raise exc.ObjectNotExecutableError(statement) from err
#    1411 else:
# -> 1412     return meth(
#    1413         self,
#    1414         distilled_parameters,
#    1415         execution_options or NO_OPTIONS,
#    1416     )
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\sql\ddl.py:181, in ExecutableDDLElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     178 def _execute_on_connection(
#     179     self, connection, distilled_params, execution_options
#     180 ):
# --> 181     return connection._execute_ddl(
#     182         self, distilled_params, execution_options
#     183     )
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:1524, in Connection._execute_ddl(self, ddl, distilled_parameters, execution_options)
#    1519 dialect = self.dialect
#    1521 compiled = ddl.compile(
#    1522     dialect=dialect, schema_translate_map=schema_translate_map
#    1523 )
# -> 1524 ret = self._execute_context(
#    1525     dialect,
#    1526     dialect.execution_ctx_cls._init_ddl,
#    1527     compiled,
#    1528     None,
#    1529     execution_options,
#    1530     compiled,
#    1531 )
#    1532 if self._has_events or self.engine._has_events:
#    1533     self.dispatch.after_execute(
#    1534         self,
#    1535         ddl,
#    (...)
#    1539         ret,
#    1540     )
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:1844, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1839     return self._exec_insertmany_context(
#    1840         dialect,
#    1841         context,
#    1842     )
#    1843 else:
# -> 1844     return self._exec_single_context(
#    1845         dialect, context, statement, parameters
#    1846     )
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:1984, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1981     result = context._setup_result_proxy()
#    1983 except BaseException as e:
# -> 1984     self._handle_dbapi_exception(
#    1985         e, str_statement, effective_parameters, cursor, context
#    1986     )
#    1988 return result
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:2339, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2337 elif should_wrap:
#    2338     assert sqlalchemy_exception is not None
# -> 2339     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2340 else:
#    2341     assert exc_info[1] is not None
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963                 break
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#    1970     self.dispatch.after_cursor_execute(
#    1971         self,
#    1972         cursor,
#    (...)
#    1976         context.executemany,
#    1977     )
#
# File c:\Users\de31\anaconda3\envs\busan_django\lib\site-packages\sqlalchemy\engine\default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# DatabaseError: (cx_Oracle.DatabaseError) ORA-02449: 외래 키에 의해 참조되는 고유/기본 키가 테이블에 있습니다
# [SQL:
# DROP TABLE disease]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)
